# %%
import pandas as pd 
import numpy as np
df = pd.read_csv("heart (5).csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.select_dtypes(include='object').columns
# Out:
# Index([], dtype='str')

# %%
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
ax=sns.countplot(x=df['target'])
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### Numerical features Distribution

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
axes = axes.flatten() 

for i, col in enumerate(features):
    sns.histplot(df[col], kde=True, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Distribution of {col}', fontsize=12)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

fig.delaxes(axes[5])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

plt.figure(figsize=(18, 5))
for i, col in enumerate(features):
    plt.subplot(1, 5, i+1)
    sns.kdeplot(df[col], fill=True, color='teal', linewidth=2)
    plt.title(f'{col} Distribution')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
axes = axes.flatten() 

for i, col in enumerate(features):
    sns.boxplot(df[col],ax=axes[i], color='skyblue')
    axes[i].set_title(f'Boxplot of {col}', fontsize=12)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

fig.delaxes(axes[5])

plt.tight_layout()
plt.show()

# %% [markdown]
# oldpeak (Skewness): The data is heavily weighted toward zero. Most patients show no ST depression, creating a "long tail" of higher values. This imbalance can make it harder for models to learn the significance of the higher values.
#
#
# Shutterstock
# Explore
# chol & trestbps (Outliers): There are extreme values (e.g., Cholesterol > 500) that stand far apart from the rest of the group. These "clinical outliers" can distort your average and mislead certain machine learning models.
#
# age (Normal Distribution): This is your most "well-behaved" feature. It follows a bell curve centered in the late 50s, meaning the dataset has a balanced representation of middle-aged and older adults.
#
# thalach (Negative Skew): Unlike other features, this one leans toward the high end (140–170 bpm). However, a single very low outlier exists, which might represent a specific medical condition or a data entry error.
#
# Multimodality: Several KDE plots (like age) show multiple "humps." This suggests your data isn't one uniform group but likely contains sub-populations (e.g., different risk levels or gender groups) mixed together.
#
# Scale Variance: The features live in completely different worlds—one goes up to 6 (oldpeak), while another goes up to 500 (chol). You must scale/standardize this data, or the model will think Cholesterol is "more important" just because the numbers are bigger.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

plt.figure(figsize=(18, 10))

for i, col in enumerate(features):
    plt.subplot(2, 3, i+1)
    sns.kdeplot(data=df, x=col, hue='target', fill=True, common_norm=False, palette='viridis', alpha=0.5)
    plt.title(f'{col} Distribution by Target')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

plt.figure(figsize=(18, 10))

for i, col in enumerate(features):
    plt.subplot(2, 3, i+1)
    
    sns.barplot(data=df, x='target', y=col, palette='muted', capsize=.1)
    
    plt.title(f'Average {col} by Target')
    plt.xlabel('Target (0 = No Disease, 1 = Disease)')
    plt.ylabel(f'Mean {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. oldpeak is a Strong Predictor
# This is the most significant differentiator. Patients with heart disease (Target 1) have a massive peak at 0, while those without disease (Target 0) have much higher average ST depression levels (~1.6 vs ~0.6).
#
# Insight: Lower oldpeak values are strongly associated with the presence of heart disease in this specific dataset.
#
# 2. thalach (Heart Rate) Divergence
# There is a clear "shift" in the distributions. Patients with heart disease generally achieve a higher maximum heart rate (mean ~160 bpm) compared to those without (mean ~140 bpm).
#
# Insight: Higher exercise heart rates are a positive indicator for Target 1.
#
# 3. Age Paradox
# Interestingly, the patients with heart disease (Target 1) in this dataset are younger on average (mean ~52) than those without disease (mean ~56).
#
# Insight: The KDE shows a distinct "hump" for Target 1 around age 40-45, suggesting a younger high-risk subgroup.
#
# 4. Overlapping Risks (trestbps & chol)
# The distributions for resting blood pressure and cholesterol are very similar for both groups.
#
# Insight: While these are health markers, they don't clearly distinguish between the two classes on their own in this dataset, as the "No Disease" group actually has slightly higher mean values.

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### Categorical Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cat_features = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 18))
axes = axes.flatten()

for i, col in enumerate(cat_features):
    sns.countplot(data=df, x=col, ax=axes[i], palette='viridis', edgecolor='black')
    
    for container in axes[i].containers:
        axes[i].bar_label(container)
        
    axes[i].set_title(f'Total Count of {col}', fontsize=14)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of categorical features
cat_features = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

# Set up the figure and axes (4 rows, 2 columns)
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(16, 20))
axes = axes.flatten()

for i, col in enumerate(cat_features):
    sns.countplot(data=df, x=col, hue='target', ax=axes[i], palette='Set2')
    axes[i].set_title(f'Count of {col} by Target', fontsize=14)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')
    axes[i].legend(title='Target', loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. The "Exang" and "CP" Indicators
# Chest Pain (cp): Patients with Category 0 (asymptomatic) are significantly less likely to have heart disease. Conversely, Categories 1, 2, and 3 show a much higher proportion of Target 1.
#
# Exercise Induced Angina (exang): This is a powerful binary predictor. If a patient does not have exercise-induced angina (Value 0), they are far more likely to have heart disease in this dataset.
#
# 2. Major Vessels and Thalassemia
# Number of Vessels (ca): The most frequent category is 0. As the number of major vessels colored by fluoroscopy increases, the likelihood of heart disease (Target 1) drops drastically.
#
# Thalassemia (thal): Category 2 is a massive indicator for Target 1, while Category 3 is strongly associated with Target 0.
#
# 3. Demographic and Lifestyle Imbalances
# Sex: The dataset is heavily skewed toward males (Category 1). Interestingly, a much higher percentage of females (Category 0) in this sample are positive for heart disease compared to the male group.
#
# Fasting Blood Sugar (fbs): Most of your population has low fasting blood sugar (< 120 mg/dl). Because the distribution of Target 0 and 1 is almost identical in both categories, fbs likely has low information gain for your Decision Tree.
#
# 4. Technical Indicators (Slope & Restecg)
# Slope: Category 2 (flat/downsloping) shows a strong correlation with heart disease, while Category 1 is more common in healthy subjects.
#
# Resting ECG (restecg): Category 1 (ST-T wave abnormality) has a higher count of Target 1 patients compared to Category 0. Category 2 is too rare (only 15 samples) to draw a strong conclusion.
#
# 5. Data Sparsity Warnings
# Be careful with ca=4 and thal=0. These have very low sample sizes (18 and 7 respectively). In a Decision Tree, these small buckets can lead to overfitting because the model might create rules based on just a handful of people.

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr_matrix = df.corr()

plt.figure(figsize=(15, 10))

sns.heatmap(corr_matrix, 
            annot=True,          
            fmt=".2f",           
            cmap='coolwarm',     
            linewidths=0.5,     
            annot_kws={"size": 10}) 

plt.title('Correlation Heatmap of All Features', fontsize=16)
plt.show()

# %% [markdown]
# 4. Multicollinearity Check
# There are no extremely high correlations (e.g., above 0.80) between independent features. This is good news—it means each feature is bringing relatively unique information to the table, reducing the need to drop columns before training your Decision Tree.

# %% [markdown]
# ### Encoding and Feature Scaling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, accuracy_score, roc_auc_score
from sklearn.preprocessing import StandardScaler


df_final = pd.get_dummies(df, columns=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal'], drop_first=True)

scaler = StandardScaler()
num_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
df_final[num_cols] = scaler.fit_transform(df_final[num_cols])

# %% [markdown]
# ### Splitting the Dataset 80:20

# %%
X = df_final.drop('target', axis=1)
y = df_final['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

dt_model = DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_split=10, random_state=42)
dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.79
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79       102
#            1       0.79      0.78      0.78       103
#
#     accuracy                           0.79       205
#    macro avg       0.79      0.79      0.79       205
# weighted avg       0.79      0.79      0.79       205

# %% [markdown]
# ### Model Evaluation and Analysis

# %%
plt.figure(figsize=(20,10))
plot_tree(dt_model, feature_names=X.columns, class_names=['No Disease', 'Disease'], filled=True, rounded=True)
plt.title("Visualized Decision Tree Rules")
plt.show()

feat_importance = pd.Series(dt_model.feature_importances_, index=X.columns)
feat_importance.nlargest(5).plot(kind='barh')
plt.title("Top 5 Important Features")
plt.show()

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

dt = DecisionTreeClassifier(random_state=42)

grid_search = GridSearchCV(estimator=dt, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

grid_search.fit(X_train, y_train)

best_dt_model = grid_search.best_estimator_

print(f"Best Parameters: {grid_search.best_params_}")
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %% [markdown]
# ### Best Model Evaluation and Analysis

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

y_pred = best_dt_model.predict(X_test)
y_prob = best_dt_model.predict_proba(X_test)[:, 1] # For ROC-AUC

metrics = {
    "Accuracy": accuracy_score(y_test, y_pred),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1-Score": f1_score(y_test, y_pred),
    "ROC-AUC": roc_auc_score(y_test, y_prob)
}

for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")

plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1-Score: 1.0000
# ROC-AUC: 1.0000

# %% [markdown]
# ## Visualize the structure

# %%
plt.figure(figsize=(25,12))
plot_tree(best_dt_model, 
          feature_names=X.columns, 
          class_names=['No Disease', 'Disease'], 
          filled=True, 
          rounded=True, 
          fontsize=10)
plt.title("Optimized Decision Tree Structure")
plt.show()

importances = pd.Series(best_dt_model.feature_importances_, index=X.columns)
importances.nlargest(10).plot(kind='barh', color='teal')
plt.title("Top 10 Features Driving Predictions")
plt.show()

# %% [markdown]
# ## Interview Questions
#
# #1 What are some common hyperparameters of decision tree models, and how do they affect the model's performance?

# %% [markdown]
# 1. Common Hyperparameters of Decision Trees
# Decision tree hyperparameters primarily control the growth of the tree to prevent overfitting.
#
# max_depth: The maximum length of the path from the root to a leaf.
#
# Effect: High depth captures complex patterns but leads to overfitting; low depth leads to underfitting (high bias).
#
# min_samples_split: The minimum number of samples a node must have before it can be split.
#
# Effect: Higher values prevent the tree from creating overly specific rules, reducing overfitting.
#
# min_samples_leaf: The minimum number of samples required to be at a leaf node.
#
# Effect: Smooths the model; higher values prevent the model from isolating single, noisy data points.
#
# criterion: The function used to measure the quality of a split (e.g., Gini Impurity or Entropy for classification; MSE or MAE for regression).

# %% [markdown]
# # 2. What is the difference between the Label encoding and One-hot encoding?

# %% [markdown]
# Label Encoding vs. One-Hot Encoding
#
# The primary difference lies in how they represent categorical data and whether they introduce an unintended numerical order.
#
# Label EncodingHow it works: Assigns a unique integer to each category (e.g., Red = 0, Green = 1, Blue = 2).
#
# Order/Rank: It implies an ordinal relationship because algorithms may interpret the assigned numbers as having a natural order ($2 > 1 > 0$).
#
# Best Used For: Ordinal data, where the categories have a natural sequence or ranking (e.g., Low = 0, Medium = 1, High = 2).
#
# Dimensionality: Keeps the dataset size the same by operating within a single column.
# One-Hot Encoding
#
# How it works: Creates a separate binary column (containing $0$ or $1$) for each unique category in the feature.
#
# Order/Rank: No relationship or ranking is implied; all categories are treated equally.
# Best Used For: Nominal data, where the categories have no inherent order (e.g., Country names, Colors).
#
# Dimensionality: Can drastically increase the number of columns (dimensionality) if a feature has many unique categories.
